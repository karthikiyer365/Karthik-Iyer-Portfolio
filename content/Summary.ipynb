# %% [markdown]
# # Experience
#
# A structured overview of my professional journey across analytics, systems, and applied machine learning.
# This notebook presents a high-level analytical summary of industries, technologies, and career progression.

# %% [markdown]
# ## Experience Breakdown

# %% [markdown]
# ### Overview
#
# This summary maps my portfolio across AI systems, data engineering, analytics, integration work, and workflow operations. The chart below combines an overlaid career-growth KDE with a concept cloud generated from my CV and portfolio source files.

# %%
from charts.build_index_summary import build_chart

# %%
fig = build_chart()
fig.show()
# Out:
# <div style="width:100%;padding:0 10px;box-sizing:border-box"><div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Roles
#
# ### [AI & Data Engineer](portfolio/experiences/AI%20%26%20Data%20Engineer%20-%20RestoreFast.ipynb) · [RestoreFast](portfolio/experiences/AI%20%26%20Data%20Engineer%20-%20RestoreFast.ipynb)
#
# ### [Teaching Assistant](portfolio/experiences/Teaching%20Assistant%20-%20GWU.ipynb) · [George Washington University](portfolio/experiences/Teaching%20Assistant%20-%20GWU.ipynb)
#
# ### [Technical Systems Admin](portfolio/experiences/Technical%20Systems%20Admin%20-%20GWU.ipynb) · [George Washington University](portfolio/experiences/Technical%20Systems%20Admin%20-%20GWU.ipynb)
#
# ### [Financial Analyst](portfolio/experiences/Financial%20Analyst%20-%20DPSY%20%26%20Associates.ipynb) · [DPSY & Associates](portfolio/experiences/Financial%20Analyst%20-%20DPSY%20%26%20Associates.ipynb)
#
# ### [SMO Lead](portfolio/experiences/SMO%20Lead%20-%20TechAnalogy.ipynb) · [TechAnalogy](portfolio/experiences/SMO%20Lead%20-%20TechAnalogy.ipynb)

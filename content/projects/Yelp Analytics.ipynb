# %% [markdown]
# # Yelp Analytics
#
# **Large-scale review ETL & sentiment analysis · Databricks · Spark · SQL**
#
# ## Hero Overview
#
# A big-data pipeline processing 10M+ Yelp data points through Databricks ETL and applying the AFINN sentiment lexicon across 7M+ reviews to surface star-rating vs. sentiment bias.
#
# Findings were packaged into sector-specific strategy directions, bridging distributed processing output to business decisions.

# %%
# Radar (skill intensity) + Bubble cluster (implementation strength).
fig
# Out:
# <div style="display:flex;flex-wrap:wrap;gap:18px;background:#111;border-radius:8px;padding:16px 18px 18px;"><div style="flex:1 1 390px;min-width:330px;"><div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Technology Capability Network — concepts ↔ tools (bipartite, D3).
# Out:
# <div id="net-wrap" style="position:relative;width:100%;background:#111;border-radius:8px;font-family:-apple-system,Segoe UI,sans-serif;">
#   <div style="color:#e5e5e5;font-size:15px;text-align:center;padding:22px 0 8px;">Technology Capability Network</div>
#   <div style="color:#8a8a8a;font-size:11px;text-align:center;padding-bottom:18px;">Maps the project's core techniques to the tools used to implement them.</div>
#   <svg id="net-svg" style="display:block;width:100%;height:820px" viewBox="0 0 980 820" preserveAspectRatio="xMidYMid meet"></svg>
#   <div id="net-tip" style="position:absolute;pointer-events:none;opacity:0;background:#1c1c1c;border:1px solid #333;border-radius:8px;padding:8px 10px;color:#e5e5e5;font-size:12px;max-width:240px;line-height:1.4;box-shadow:0 4px 16px rgba(0,0,0,.5);z-index:10;"></div>
# </div>
# <script src="https://cdn.jsdelivr.net/npm/d3@7/dist/d3.min.js"></script>
# <script>
# (function(){
# ...

# %%
outcomes = {
    "Data Points Processed": "10M+",
    "Reviews Analyzed": "7M+",
    "ETL Pipelines": "5+",
    "Processing Time Saved": "~15 hrs",
    "Sector Patterns": "3"
}

pd.DataFrame(outcomes.items(), columns=["Metric", "Value"])
# Out:
# <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metric</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Data Points Processed</td>
#       <td>10M+</td>
#     </tr>
#     <tr>
#       <td>Reviews Analyzed</td>
#       <td>7M+</td>
#     </tr>
#     <tr>
#       <td>ETL Pipelines</td>
#       <td>5+</td>
#     </tr>
#     <tr>
#       <td>Processing Time Saved</td>
#       <td>~15 hrs</td>
#     </tr>
#     <tr>
#       <td>Sector Patterns</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Storyline
#
# ## Context
#
# Millions of Yelp reviews held category-level behavioral signal, but raw star ratings alone obscured how sentiment actually diverged across business sectors.
#
# ## Workflow
#
# Distributed ingestion & transformation → sentiment scoring at scale → sector pattern detection → stakeholder-facing strategy report.
#
# ## Technical Implementation
#
# - **ETL:** 5+ Databricks/Spark pipelines transforming 10M+ data points with SQL, cutting end-to-end processing ~15 hours.
# - **Sentiment:** AFINN lexicon applied to 7M+ reviews with Spark, exposing star-rating vs. sentiment bias by category.
# - **Insight:** 3 sector-specific behavior patterns (restaurants, salons, retail) grounded in review-sentiment evidence.
#
# ## Outcomes
#
# Bridged Databricks ETL output to business strategy, translating large-scale review data into 3 actionable, category-aligned strategy directions.

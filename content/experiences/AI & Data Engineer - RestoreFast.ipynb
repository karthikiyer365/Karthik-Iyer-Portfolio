# %% [markdown]
# # RestoreFast · AI & Data Engineer
#
# **Jun 2025 – Present · North Bethesda, MD**
#
# ## Hero Overview
#
# Architected and built the operational AI systems behind RestoreFast's workforce platform — agentic worker matching, a retrieval-augmented knowledge layer, a 24/7 hotline triage agent, cross-tool communications routing, and compliance document management.
#
# Connected fragmented tools (Gmail, Drive, Nutshell, Xero, Twilio) into a unified internal data layer, turning manual, siloed workflows into a connected pipeline from worker discovery through project execution.

# %%
# Radar (skill intensity) + Bubble cluster (implementation strength).
fig
# Out:
# <div style="display:flex;flex-wrap:wrap;gap:18px;background:#111;border-radius:8px;padding:16px 18px 18px;"><div style="flex:1 1 390px;min-width:330px;"><div>                        <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.1.min.js" integrity="sha256-4rD3fugVb/nVJYUv5Ky3v+fYXoouHaBSP20WIJuEiWg=" crossorigin="anonymous"></script>                <div id="radar" class="plotly-graph-div" style="height:500px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("radar")) {                    Plotly.newPlot(                        "radar",                        [{"fill":"toself","fillcolor":"rgba(221,0,119,0.25)","hovertemplate":"%{theta}: %{r}\u003cextra\u003e\u003c\u002fextra\u003e","line":{"color":"#dd0077"},"r":[8,9,8,8,7,5,7,3,8],"theta":["AI \u002f ML","Data Engineering","Backend Engineering","Systems Integration","Workflow \u002f Product","Cloud & Infra","Operations \u002f Automation","Analytics \u002f Insights","AI \u002f ML"],"type":"scatterpolar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#f2f5fa"},"error_y":{"color":"#f2f5fa"},"marker":{"line":{"color":"rgb(17,17,17)","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"baxis":{"endlinecolor":"#A2B1C6","gridcolor":"#506784","linecolor":"#506784","minorgridcolor":"#506784","startlinecolor":"#A2B1C6"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattergeo"}],"scattergl":[{"marker":{"line":{"color":"#283442"}},"type":"scattergl"}],"scattermapbox":[{"marke ...

# %%
# Technology Capability Network — concepts ↔ tools (bipartite, D3).
# Out:
# <div id="net-wrap" style="position:relative;width:100%;background:#111;border-radius:8px;font-family:-apple-system,Segoe UI,sans-serif;">
#   <div style="color:#e5e5e5;font-size:15px;text-align:center;padding:22px 0 8px;">Technology Capability Network</div>
#   <div style="color:#8a8a8a;font-size:11px;text-align:center;padding-bottom:18px;">Maps core technical concepts to the tools and platforms used to implement them.</div>
#   <svg id="net-svg" style="display:block;width:100%;height:820px" viewBox="0 0 980 820" preserveAspectRatio="xMidYMid meet"></svg>
#   <div id="net-tip" style="position:absolute;pointer-events:none;opacity:0;background:#1c1c1c;border:1px solid #333;border-radius:8px;padding:8px 10px;color:#e5e5e5;font-size:12px;max-width:240px;line-height:1.4;box-shadow:0 4px 16px rgba(0,0,0,.5);z-index:10;"></div>
# </div>
# <script src="https://cdn.jsdelivr.net/npm/d3@7/dist/d3.min.js"></script>
# <script>
# (function start(){
#   // Wait until d3 (loaded from the CDN <script> above) is available.
#   // On remounted srcdoc iframes the external script can resolve after this
#   // inline script first runs, so poll instead of assuming d3 is ready.
#   if (typeof d3 === "undefined") { return setTimeout(start, 30); }
#   var NODES=[{"id": "Worker Matching", "type": "system", "domain": "AI / ML", "color": "#dd0077", "x": 150, "y": 170.5, "r": 18.5}, {"id": "Knowledge Layer", "type": "system", "domain": "Data Engineering", "color": "#7cc2b3", "x": 150, "y": 339.5, "r": 17.2}, {"id": "Comms Infra", "type": "system", "domain": "Integration", "color": "#cd6e98", "x": 150, "y": 508.5, "r": 19.8}, {"id": "Compliance Ops", "type": "system", "domain": "Workflow / Ops", "color": "#4ec9b0", "x": 150, "y": 677.5, "r": 16.0}, {"id": "Agentic AI", "type": "concept", "domain": "AI / ML", "color": "#dd0077", "x": 490, "y": 142.3, "r": 19.8}, {"id": "RAG", "type": "concept", "domain": "AI / ML", "color": "#dd0077", "x": 490, "y": 255.0, "r": 24.8}, {"id": "MCP Tools", "type": "concept", "domain": "Integration", "color": "#cd6e98", "x": 490, "y": 367.7, "r": 26.0}, {"id": "Workflow Automation", "type": "concept", "domain": "Workflow / Ops", "color": "#4ec9b0", "x": 490, "y": 480.3, "r": 22.2}, {"id": "LLM Apps", "type": "concept", "domain": "AI / ML", "color": "#dd0077", "x": 490, "y": 593.0, "r": 18.5}, {"id": "Integrations", "type": "concept", "domain": "Integration", "color": "#cd6e98", "x": 490, "y": 705.7, "r": 24.8}, {"id": "Python / SQL", "type": "tool", "category": "Language", "color": "#6e6e6e", "x": 830, "y": 142.3, "r": 19.8}, {"id": "Supabase", "type": "tool", "category": "Database", "color": "#6e6e6e", "x": 830, "y": 255.0, "r": 17.2}, {"id": "Pinecone", "type": "tool", "category": "AI Framework", "color": "#6e6e6e", "x": 830, "y": 367.7, "r": 16.0}, {"id": "Twilio", "type": "tool", "category": "Communications", "color": "#6e6e6e", "x": 830, "y": 480.3, "r": 12.2}, {"id": "Gmail / Drive", "type": "tool", "category": "Workspace APIs", "color": "#6e6e6e", "x": 830, "y": 593.0, "r": 17.2}, {"id": "Docker / AWS", "type": "tool", "category": "Cloud / Containers", "color": "#6e6e6e", "x": 830, "y": 705.7, "r": 11.0}], EDGES=[{"source": "Worker Matching", "target": "Agentic AI", "weight": 3}, {"source": "Worker Matching", "target": "MCP Tools", "weight": 2}, {"source": "Worker Matching", "target": "LLM Apps", "weight": 2}, {"source": "Worker Matching", "target": "Integrations", "weight": 2}, {"source": "Knowledge Layer", "target": "RAG", "weight": 3}, {"source": "Knowledge Layer", "target": "MCP Tools", "weight": 2}, {"source": "Knowledge Layer", "target": "Integrations", "weight": 2}, {"source": "Knowledge Layer", "target": "Workflow Automation", "weight": 1}, {"source": "Comms Infra", "target": "Workflow Automation", "weight": 3}, {"source": "Comms Infra", "target": "Integrations", "weight": 3}, {"source": "Comms Infra", "target": "LLM Apps", "weight": 2}, {"source": "Comms Infra", "target": "MCP Tools", "weight": 2}, {"source": "Compliance Ops", "target": "Workflow Automation", "weight": 3}, {"source": "Compliance Ops", "target": "RAG", "weight": 2}, {"source": "Compliance Ops", "target": "Integrations", "weight": 2}, {"source": "Agentic AI", "target": "Python / SQL", "weight": 3}, {"source": "Agentic AI", "target": "Pinecone", "weight": 2}, {"source": "Agentic AI", "target": "Supabase", "weight": 2}, {"source": "RAG", "target": "Pinecone", "weight": 3}, {"source": "RAG", "target": "Supabase", "weight": 2}, {"source": "RAG", "target": "Python / SQL", "weight": 2}, {"source": "MCP Tools", "target": "Gmail / Drive", "weight": 3}, {"source": "MCP Tools", "target": "Twilio", "weight": 2}, {"source": "MCP Tools", "target": "Python / SQL", "weight": 2}, {"source": "Workflow Automation", "target": "Docker / AWS", "weight": 3}, {"source": "Workflow Automation", "target": "Twilio", "weight": 2}, {"source": "LLM Apps", "target": "Python / SQL", "weight": 3}, {"source": "LLM Apps", "target": "Pinecone", "weight": 2}, {"source": "Integrations", "target": "Gmail / Drive", "weight": 3}, {"source": "Integrations", "target": "Supabase", "weight": 2}, {"source": "RAG", "target": "Gmail / Drive", "weight": 2}, {"source": "MCP Tools", "target": "Supabase", "weight": 2} ...
#   var svg=d3.select("#net-svg"), tip=d3.select("#net-tip"), wrap=document.getElementById("net-wrap");
#   var pos={}; NODES.forEach(function(n){ pos[n.id]=n; });
#   var adj={}; NODES.forEach(function(n){ adj[n.id]={}; });
#   EDGES.forEach(function(e){ adj[e.source][e.target]=1; adj[e.target][e.source]=1; });
#
#   var g=svg.append("g");
#
#   // edges as horizontal cubic curves, width = weight
#   var edge=g.append("g").selectAll("path").data(EDGES).enter().append("path")
#     .attr("fill","none").attr("stroke","#666")
#     .attr("stroke-opacity",function(d){return 0.18+d.weight*0.06;})
#     .attr("stroke-width",function(d){return d.weight;})
#     .attr("d",function(d){
#       var s=pos[d.source], t=pos[d.target], mx=(s.x+t.x)/2;
#       return "M"+s.x+","+s.y+" C"+mx+","+s.y+" "+mx+","+t.y+" "+t.x+","+t.y;
#     });
#
#   var node=g.append("g").selectAll("g.node").data(NODES).enter().append("g")
#     .attr("transform",function(d){return "translate("+d.x+","+d.y+")";})
#     .style("cursor","default")
#     .on("mousemove",function(ev,d){
#       var b=wrap.getBoundingClientRect();
#       var meta=(d.type==="tool")?("tool · "+d.category):(d.type+" · "+d.domain);
#       tip.style("opacity",1).style("left",(ev.clientX-b.left+12)+"px").style("top",(ev.clientY-b.top+12)+"px")
#          .html("<b>"+d.id+"</b><br><span style='color:#9a9a9a'>"+meta+"</span>");
#       edge.attr("stroke-opacity",function(e){return (e.source===d.id||e.target===d.id)?0.85:0.04;})
#           .attr("stroke",function(e){return (e.source===d.id||e.target===d.id)?"#dd0077":"#666";});
#       node.attr("opacity",function(n){return (n.id===d.id||adj[d.id][n.id])?1:0.25;});
#     })
#     .on("mouseleave",function(){
#       tip.style("opacity",0);
#       edge.attr("stroke-opacity",function(d){return 0.18+d.weight*0.06;}).attr("stroke","#666");
#       node.attr("opacity",1);
#     });
#
#   node.append("circle").attr("r",function(d){return d.r;})
#     .attr("fill",function(d){return d.color;})
#     .attr("fill-opacity",function(d){return d.type==="tool"?0.85:0.92;})
#     .attr("stroke","#111").attr("stroke-width",function(d){return d.type==="tool"?1.2:2;});
#
#   // labels: systems -> left, tools -> right, concepts (middle) -> above
#   node.append("text").text(function(d){return d.id;})
#     .attr("text-anchor",function(d){return d.type==="system"?"end":(d.type==="tool"?"start":"middle");})
#     .attr("x",function(d){return d.type==="system"?-(d.r+7):(d.type==="tool"?(d.r+7):0);})
#     .attr("dy",function(d){return d.type==="concept"?-(d.r+5):4;})
#     .attr("fill","#cfcfcf").attr("font-size","10.5px")
#     .attr("font-weight",function(d){return d.type==="tool"?"400":"600";})
#     .style("pointer-events","none");
#
#   // column captions, one per present column
#   var cols={}; NODES.forEach(function(n){ if(!(n.type in cols)) cols[

# %%
outcomes = {
    "Profiles Evaluated": "400+",
    "Routine Escalations Reduced": "~60%",
    "Internal Tools Routed": "15+",
    "Platforms Integrated": "5+",
    "Active Projects": "5+"
}

pd.DataFrame(outcomes.items(), columns=["Metric", "Value"])
# Out:
# <table class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metric</th>
#       <th>Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Profiles Evaluated</td>
#       <td>400+</td>
#     </tr>
#     <tr>
#       <td>Routine Escalations Reduced</td>
#       <td>~60%</td>
#     </tr>
#     <tr>
#       <td>Internal Tools Routed</td>
#       <td>15+</td>
#     </tr>
#     <tr>
#       <td>Platforms Integrated</td>
#       <td>5+</td>
#     </tr>
#     <tr>
#       <td>Active Projects</td>
#       <td>5+</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Storyline
#
# ## Context
#
# RestoreFast's operations ran across disconnected third-party tools with no unified data layer — worker discovery, compliance, and client communication each lived in a silo, slowing project execution and burying staff in manual triage.
#
# ## Workflow
#
# The platform connects worker discovery → evaluation & matching → onboarding & compliance → live project communication, with an AI knowledge layer and a 24/7 hotline agent across the flow to triage inbound work and surface answers from internal data.
#
# ## Technical Implementation
#
# - **Agentic matching (DS-CAR):** multi-step agentic flows that identify, evaluate, and select worker profiles against project requirements across five dimensions, wired into integrated communication channels.
# - **Integration layer:** 5+ third-party platforms (Gmail, Drive, Nutshell, Xero, Twilio) unified through custom MCP tools, RAG connectors, and REST services.
# - **Knowledge platform:** ingestion and retrieval layer over connected Agentic/RAG/MCP setups on Pinecone with custom schema design.
# - **Hotline agent:** 24/7 LLM-backed tier-1 call triage on a queued audio-processing backend with Twilio, cutting routine escalations ~60%.
# - **Communications layer:** event routing from 15+ internal tools to SMS, Voice, and Email through a containerized Twilio integration.
# - **Compliance hub:** document hub with expiration tracking and attachment references across 5+ active projects on Supabase + S3.
#
# ## Outcomes
#
# Consolidated five fragmented operational areas into connected systems, reduced routine call escalations ~60%, and gave the team a single AI-assisted layer across worker discovery, compliance, and communication.
